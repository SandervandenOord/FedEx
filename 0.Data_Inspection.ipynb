# %% [markdown]
# # 0. Data Inspection: this dataset is problematic
#
# Largest issues:
# - no customer id in Table ListOfOrders, only customer first name + last name. So we cannot for sure connect customers to orders
# - no primary keys in the tables
# - customer id in CustomerList1 is a real value, but customer is in CustomerList2 is an integer
# - 7 missing values for customer id in table CustomerList1
# - order items also don't have an id, just a name of the product
# - dataset is limited and there is no guarantee that these are all orders
# - dataset doesn't contain a margin field, so we cannot say much about profitability
#
# *In essence we can only do some exploration, but no real conclusions on profitability etc.*

# %%
import numpy as np
import pandas as pd
import sqlite3

# %%
sqlite_connection = sqlite3.connect('assessment_database.sqlite')

# %%
tables_query = """
    SELECT name 
    FROM sqlite_master 
    WHERE type='table';
"""

df_tables = pd.read_sql(tables_query, sqlite_connection)
df_tables
# Out:
#                 name
# 0      CustomerList1
# 1      CustomerList2
# 2       ListOfOrders
# 3     OrderBreakdown
# 4  customers_cleaned

# %%
# no primary keys!!

# Customer_id in table1 has datatype REAL and Customer_id in table2 has datatype INTEGER

# ListOfOrders: No CustomerId in table ListOfOrders ?! Only Customer Name

# OrderBreakdown: Total revenue before discount is a text field?!

for table_name in df_tables['name']:
    table_info_query = f"""PRAGMA table_info({table_name})"""
    table_info = pd.read_sql(table_info_query, sqlite_connection)
    print(table_name.upper(), table_info, sep='\n', end='\n\n')
# Out:
# CUSTOMERLIST1
#    cid                    name       type  notnull dflt_value  pk
# 0    0                   index    INTEGER        0       None   0
# 1    1             Customer_id       REAL        0       None   0
# 2    2                    Name       TEXT        0       None   0
# 3    3                 Surname       TEXT        0       None   0
# 4    4                 country       TEXT        0       None   0
# 5    5                  Gender       TEXT        0       None   0
# 6    6                     Age       REAL        0       None   0
# 7    7  Date Registered Online  TIMESTAMP        0       None   0
#
# CUSTOMERLIST2
#    cid                    name       type  notnull dflt_value  pk
# 0    0                   index    INTEGER        0       None   0
# 1    1             Customer_id    INTEGER        0       None   0
# 2    2                    Name       TEXT        0       None   0
# 3    3                 Surname       TEXT        0       None   0
# 4    4                 country       TEXT        0       None   0
# 5    5                  Gender       TEXT        0       None   0
# 6    6                     Age       REAL        0       None   0
# 7    7  Date Registered Online  TIMESTAMP        0       None   0
#
# LISTOFORDERS
#    cid            name     type  notnull dflt_value  pk
# 0    0           index  INTEGER        0       None   0
# 1    1        Order ID     TEXT        0       None   0
# 2    2  Oder_date_time     TEXT        0       None   0
# 3    3   Customer Name     TEXT        0       None   0
#
# ORDERBREAKDOWN
#    cid                           name     type  notnull dflt_value  pk
# 0    0                          index  INTEGER        0       None   0
# 1    1                       Order ID     TEXT        0       None   0
# 2    2                   Product Name     TEXT        0       None   0
# 3    3           Discount per product     REAL        0       None   0
# 4    4  Total revenue before discount     TEXT        0       None   0
# 5    5                 Total quantity     REAL        0       None   0
# 6    6                       Category     TEXT        0       None   0
#
# CUSTOMERS_CLEANED
#    cid                    name type  notnull dflt_value  pk
# 0    0             customer_id  INT        0       None   0
# 1    1                    name             0       None   0
# 2    2                 surname             0       None   0
# 3    3                 country             0       None   0
# 4    4                  gender             0       None   0
# 5    5                     age             0       None   0
# 6    6  date_registered_online             0       None   0

# %%
# 749 customer rows in list 1

# need to convert customer_id to int 

customer_list1_query = """SELECT * FROM CustomerList1"""

df_customer_list1 = pd.read_sql(customer_list1_query, sqlite_connection, index_col='index')
df_customer_list1
# Out:
#        Customer_id     Name     Surname         country  Gender   Age  \
# index
# 0      350714120.0    Aaron     Bergman  United Kingdom    male  48.0
# 1      370582569.0    Aaron     Hawkins  United Kingdom    male  64.0
# 2      229469415.0    Aaron    Smayling  United Kingdom    male  29.0
# 3      211644956.0     Adam  Bellavance  United Kingdom    male  41.0
# 4      131647193.0     Adam        Hart  United Kingdom    male  30.0
# ...            ...      ...         ...             ...     ...   ...
# 744    272070547.0   Thomas    Thornton           Spain    male  55.0
# 745    334707196.0  Tiffany       House     Switzerland  female  49.0
# 746    269572786.0      Tim    Brockman           Spain    male  53.0
# 747    304366203.0      Tim     Taslimi  United Kingdom    male  55.0
# 748    351403245.0     Toby  Braunhardt  United Kingdom    male  56.0
#
#       Date Registered Online
# index
# 0        2011-01-17 00:00:00
# 1        2011-05-31 00:00:00
# 2        2011-02-17 00:00:00
# 3        2012-12-08 00:00:00
# 4        2011-04-11 00:00:00
# ...                      ...
# 744      2011-09-18 00:00:00
# 745      2011-07-20 00:00:00
# 746      2011-08-25 00:00:00
# 747      2013-09-10 00:00:00
# 748      2011-12-12 00:00:00
#
# [749 rows x 7 columns]

# %%
df_customer_list1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 749 entries, 0 to 748
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_id             742 non-null    float64
#  1   Name                    688 non-null    object
#  2   Surname                 688 non-null    object
#  3   country                 743 non-null    object
#  4   Gender                  721 non-null    object
#  5   Age                     722 non-null    float64
#  6   Date Registered Online  741 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 46.8+ KB

# %%
# 7 missing values for customer id

df_customer_list1.isna().sum()
# Out:
# Customer_id                7
# Name                      61
# Surname                   61
# country                    6
# Gender                    28
# Age                       27
# Date Registered Online     8
# dtype: int64

# %%
df_customer_list1.nunique()
# Out:
# Customer_id               742
# Name                      313
# Surname                   532
# country                    12
# Gender                      3
# Age                        59
# Date Registered Online    490
# dtype: int64

# %%
# rows with missing values

df_customer_list1[df_customer_list1.isna().sum(axis=1) >= 1]
# Out:
#        Customer_id    Name Surname         country  Gender   Age  \
# index
# 10     301686124.0    None    None  United Kingdom    None   NaN
# 21     321069499.0    None    None  United Kingdom    None   NaN
# 44     361656560.0    None    None  United Kingdom    None   NaN
# 45     133222542.0    None    None  United Kingdom    None   NaN
# 57     299147547.0    None    None         Germany    None   NaN
# ...            ...     ...     ...             ...     ...   ...
# 688    194251595.0    None    None  United Kingdom    male  58.0
# 701    345994702.0    None    None  United Kingdom  female  52.0
# 716    139007107.0  Stuart    None     Switzerland    male  53.0
# 724    162615482.0   Susan    None  United Kingdom  female  51.0
# 743    346657551.0  Thomas    None  United Kingdom    male  56.0
#
#       Date Registered Online
# index
# 10       2010-12-20 00:00:00
# 21       2011-05-22 00:00:00
# 44       2010-12-16 00:00:00
# 45       2011-07-24 00:00:00
# 57                      None
# ...                      ...
# 688      2011-08-26 00:00:00
# 701      2011-09-20 00:00:00
# 716      2011-01-13 00:00:00
# 724      2011-11-10 00:00:00
# 743      2011-08-25 00:00:00
#
# [80 rows x 7 columns]

# %%
# customers without id

df_customer_list1[df_customer_list1['Customer_id'].isna()]
# Out:
#        Customer_id      Name   Surname         country  Gender   Age  \
# index
# 385            NaN      John    Huston  United Kingdom    male  38.0
# 432            NaN      None      None           Italy  female  41.0
# 488            NaN      None      None            None  female  53.0
# 532            NaN  Michelle  Lonsdale  United Kingdom  female  41.0
# 559            NaN    Nathan     Mautz  United Kingdom    male  48.0
# 584            NaN   Patrick   Gardner         Germany    male  48.0
# 669            NaN      None      None  United Kingdom    male  56.0
#
#       Date Registered Online
# index
# 385      2011-03-30 00:00:00
# 432      2011-03-09 00:00:00
# 488      2012-09-22 00:00:00
# 532      2011-05-09 00:00:00
# 559      2013-06-01 00:00:00
# 584      2011-12-06 00:00:00
# 669      2011-12-12 00:00:00

# %%
# max age = 999, min age = 0, and also missing age values 

df_customer_list1.describe(include='all')
# Out:
#          Customer_id     Name Surname         country Gender         Age  \
# count   7.420000e+02      688     688             743    721  722.000000
# unique           NaN      313     532              12      3         NaN
# top              NaN  Michael   Jones  United Kingdom   male         NaN
# freq             NaN       10       5             446    438         NaN
# mean    2.486832e+08      NaN     NaN             NaN    NaN   50.121884
# std     8.490759e+07      NaN     NaN             NaN    NaN   36.845542
# min     1.002696e+08      NaN     NaN             NaN    NaN    0.000000
# 25%     1.771247e+08      NaN     NaN             NaN    NaN   42.250000
# 50%     2.459066e+08      NaN     NaN             NaN    NaN   50.000000
# 75%     3.234661e+08      NaN     NaN             NaN    NaN   55.000000
# max     3.996676e+08      NaN     NaN             NaN    NaN  999.000000
#
#        Date Registered Online
# count                     741
# unique                    490
# top       2011-06-13 00:00:00
# freq                        7
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
# 693 customer rows in list 2

customer_list2_query = """SELECT * FROM CustomerList2"""

df_customer_list2 = pd.read_sql(customer_list2_query, sqlite_connection, index_col='index')
df_customer_list2
# Out:
#        Customer_id      Name    Surname         country  Gender   Age  \
# index
# 0        334708301   Bradley     Nguyen  United Kingdom    male  50.0
# 1        389480478   Bradley    Talbott  United Kingdom    male  61.0
# 2        330461776    Brenda     Bowman        Portugal    male  37.0
# 3        243694808   Brendan     Dodson  United Kingdom    male  33.0
# 4        386215654   Brendan      Murry          France    male  47.0
# ...            ...       ...        ...             ...     ...   ...
# 688      250075723    Xylona      Preis           Italy  female  52.0
# 689      142739362      Yana   Sorensen         Germany  female  56.0
# 690      374315300    Yoseph    Carroll  United Kingdom    male  55.0
# 691      232501295  Zuschuss    Carroll  United Kingdom    male  52.0
# 692      226558292  Zuschuss  Donatelli          Norway    male  49.0
#
#       Date Registered Online
# index
# 0        2012-09-05 00:00:00
# 1        2012-08-02 00:00:00
# 2        2012-05-27 00:00:00
# 3        2011-05-13 00:00:00
# 4        2014-04-26 00:00:00
# ...                      ...
# 688      2013-04-27 00:00:00
# 689      2011-10-21 00:00:00
# 690      2011-03-16 00:00:00
# 691      2011-09-22 00:00:00
# 692      2011-02-20 00:00:00
#
# [693 rows x 7 columns]

# %%
df_customer_list2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 693 entries, 0 to 692
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer_id             693 non-null    int64
#  1   Name                    658 non-null    object
#  2   Surname                 658 non-null    object
#  3   country                 693 non-null    object
#  4   Gender                  693 non-null    object
#  5   Age                     691 non-null    float64
#  6   Date Registered Online  693 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 43.3+ KB

# %%
df_customer_list2.isna().sum()
# Out:
# Customer_id                0
# Name                      35
# Surname                   35
# country                    0
# Gender                     0
# Age                        2
# Date Registered Online     0
# dtype: int64

# %%
df_customer_list2.nunique()
# Out:
# Customer_id               693
# Name                      292
# Surname                   480
# country                    12
# Gender                      3
# Age                        50
# Date Registered Online    466
# dtype: int64

# %%
# rows with missing values

# age can also be 0? must check age ranges... There is also an age 999

df_customer_list2[df_customer_list2.isna().sum(axis=1) >= 1]
# Out:
#        Customer_id    Name Surname         country  Gender   Age  \
# index
# 9        346199714    None    None  United Kingdom    male  36.0
# 79       283858641    None    None  United Kingdom    male  42.0
# 89       304822153    None    None     Netherlands    male  55.0
# 91       303834481    None    None          Sweden  female  57.0
# 94       341075326    None    None  United Kingdom    male  66.0
# 113      245230286    None    None  United Kingdom    male  42.0
# 120      131513287    None    None  United Kingdom  female  33.0
# 138      197622646    None    None  United Kingdom  female  51.0
# 169      308555312    None    None           Spain  female  34.0
# 174      332393051    None    None  United Kingdom    male  66.0
# 201      281749419    None    None         Germany    male  36.0
# 207      353702633    None    None  United Kingdom    male  56.0
# 215      145043367    None    None  United Kingdom    male   0.0
# 228      271862272    None    None  United Kingdom  female  52.0
# 240      340939062    None    None     Netherlands    male  56.0
# 241      363598097    None    None  United Kingdom    male  46.0
# 276      116156919    None    None  United Kingdom    male  43.0
# 330      195427293    None    None        Portugal    male  47.0
# 335      126757916    None    None  United Kingdom  female  45.0
# 345      117400319    None    None           Spain  female  48.0
# 359      241279712    None    None           Spain  female  54.0
# 382      388363742    None    None     Netherlands  female  53.0
# 387      106418665    None    None           Spain  female  49.0
# 392      194457575    None    None         Germany  female  41.0
# 399      284078970    None    None          Sweden  female  55.0
# 425      252899945    None    None  United Kingdom    male  41.0
# 434      193847249    None    None  United Kingdom  female  51.0
# 467      392073829    None    None  United Kingdom    male  58.0
# 487      158445907    None    None  United Kingdom    male  55.0
# 533      288269508    Rick  Wilson  United Kingdom    male   NaN
# 549      377267883    None    None  United Kingdom  female  53.0
# 555      364591570    None    None  United Kingdom    male  57.0
# 562      221789222    None    None         Germany  female  50.0
# 566      308533626    None    None          France    male  56.0
# 645      272070547    None    None           Spain    male  55.0
# 669      398263425    None    None  United Kingdom  female  55.0
# 686      170318248  Vivian  Mathis  United Kingdom  female   NaN
#
#       Date Registered Online
# index
# 9        2011-08-04 00:00:00
# 79       2011-12-25 00:00:00
# 89       2011-04-20 00:00:00
# 91       2011-05-10 00:00:00
# 94       2011-06-17 00:00:00
# 113      2011-10-23 00:00:00
# 120      2011-04-11 00:00:00
# 138      2011-03-16 00:00:00
# 169      2013-05-13 00:00:00
# 174      2010-12-08 00:00:00
# 201      2012-01-15 00:00:00
# 207      2010-12-22 00:00:00
# 215      2011-07-29 00:00:00
# 228      2012-12-17 00:00:00
# 240      2011-05-27 00:00:00
# 241      2011-05-31 00:00:00
# 276      2011-11-16 00:00:00
# 330      2011-07-19 00:00:00
# 335      2012-01-10 00:00:00
# 345      2011-08-18 00:00:00
# 359      2012-08-05 00:00:00
# 382      2011-04-01 00:00:00
# 387      2012-08-02 00:00:00
# 392      2012-08-03 00:00:00
# 399      2011-04-14 00:00:00
# 425      2011-01-26 00:00:00
# 434      2011-05-09 00:00:00
# 467      2011-08-16 00:00:00
# 487      2011-01-26 00:00:00
# 533      2011-09-11 00:00:00
# 549      2011-05-06 00:00:00
# 555      2011-10-19 00:00:00
# 562      2011-06-08 00:00:00
# 566      2014-08-27 00:00:00
# 645      2011-09-18 00:00:00
# 669      2012-05-31 00:00:00
# 686      2011-12-07 00:00:00

# %%
# max age = 999, min age = 0, and also missing age values 

df_customer_list2.describe(include='all')
# Out:
#          Customer_id     Name  Surname         country Gender         Age  \
# count   6.930000e+02      658      658             693    693  691.000000
# unique           NaN      292      480              12      3         NaN
# top              NaN  Michael  Carroll  United Kingdom   male         NaN
# freq             NaN        9        5             409    411         NaN
# mean    2.498481e+08      NaN      NaN             NaN    NaN   50.771346
# std     8.526650e+07      NaN      NaN             NaN    NaN   37.201953
# min     1.002696e+08      NaN      NaN             NaN    NaN    0.000000
# 25%     1.782263e+08      NaN      NaN             NaN    NaN   45.000000
# 50%     2.475545e+08      NaN      NaN             NaN    NaN   51.000000
# 75%     3.240252e+08      NaN      NaN             NaN    NaN   55.000000
# max     3.996676e+08      NaN      NaN             NaN    NaN  999.000000
#
#        Date Registered Online
# count                     693
# unique                    466
# top       2011-06-13 00:00:00
# freq                        7
# mean                      NaN
# std                       NaN
# min                       NaN
# 25%                       NaN
# 50%                       NaN
# 75%                       NaN
# max                       NaN

# %%
# 4117 orders

# no customer id, only customer name and the name is first name + last name

order_query = """SELECT * FROM ListOfOrders"""

df_orders = pd.read_sql(order_query, sqlite_connection, index_col='index')
df_orders
# Out:
#               Order ID       Oder_date_time       Customer Name
# index
# 0      IT-2014-3675672   2014-3-11 10:17:42       Aaron Bergman
# 1      IT-2014-1559800     2014-2-7 23:0:48       Aaron Bergman
# 2      ES-2012-4291867   2012-3-12 18:17:46       Aaron Bergman
# 3      ES-2014-3856656   2014-4-23 21:48:53       Aaron Bergman
# 4      ES-2011-4184901    2011-8-30 15:7:28       Aaron Bergman
# ...                ...                  ...                 ...
# 4112   ES-2011-4052630    2011-2-21 1:48:37  Zuschuss Donatelli
# 4113   IT-2012-2197138    2012-7-13 7:22:40  Zuschuss Donatelli
# 4114   IT-2012-4926272    2012-8-17 2:39:31  Zuschuss Donatelli
# 4115   IT-2012-3146139  2012-12-12 17:45:51  Zuschuss Donatelli
# 4116   ES-2011-2379967  2011-11-22 14:35:17  Zuschuss Donatelli
#
# [4117 rows x 3 columns]

# %%
df_orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4117 entries, 0 to 4116
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order ID        4117 non-null   object
#  1   Oder_date_time  4117 non-null   object
#  2   Customer Name   4117 non-null   object
# dtypes: object(3)
# memory usage: 128.7+ KB

# %%
# no missing values

df_orders.isna().sum()
# Out:
# Order ID          0
# Oder_date_time    0
# Customer Name     0
# dtype: int64

# %%
# all 4417 are unique order_ids

df_orders.nunique()
# Out:
# Order ID          4117
# Oder_date_time    4117
# Customer Name      792
# dtype: int64

# %%
# rows with missing values (there are no missing values here in any rows)

df_orders[df_orders.isna().sum(axis=1) >= 1]
# Out:
# Empty DataFrame
# Columns: [Order ID, Oder_date_time, Customer Name]
# Index: []

# %%
# 8047 order breakdown items

# no order item id

# there are two rows with Total revenue before discount have value 'unknown', so those get first replaced by np.nan

order_breakdown_query = """SELECT * FROM OrderBreakdown"""

df_order_breakdown = pd.read_sql(order_breakdown_query, sqlite_connection, index_col='index')
df_order_breakdown['Total revenue before discount'] = df_order_breakdown['Total revenue before discount'].replace('unknown', np.nan).astype(float)
df_order_breakdown
# Out:
#               Order ID                            Product Name  \
# index
# 0      ES-2011-1001989            Cardinal 3-Hole Punch, Clear
# 1      ES-2011-1010958          Cardinal 3-Hole Punch, Economy
# 2      ES-2011-1010958      Cameo Peel and Seal, Security-Tint
# 3      ES-2011-1012469         Cardinal Binding Machine, Clear
# 4      ES-2011-1043483            Xerox Message Books, Premium
# ...                ...                                     ...
# 8042   IT-2014-5975833                 Hoover Microwave, Black
# 8043   IT-2014-5984498     Sauder 3-Shelf Cabinet, Traditional
# 8044   IT-2014-5989338                     Eldon Lockers, Blue
# 8045   IT-2014-5992832  Avery Legal Exhibit Labels, Adjustable
# 8046   IT-2014-5992832                     Eldon Lockers, Blue
#
#        Discount per product  Total revenue before discount  Total quantity  \
# index
# 0                       3.0                          229.0             9.0
# 1                       0.0                           58.0             2.0
# 2                       0.0                          140.0             6.0
# 3                       0.0                          148.0             3.0
# 4                       0.0                          224.0            11.0
# ...                     ...                            ...             ...
# 8042                    3.0                          832.0             3.0
# 8043                   15.0                           83.0             1.0
# 8044                    3.0                         1603.0             9.0
# 8045                    0.0                           74.0             8.0
# 8046                    3.0                          534.0             3.0
#
#               Category
# index
# 0      Office Supplies
# 1      Office Supplies
# 2      Office Supplies
# 3      Office Supplies
# 4      Office Supplies
# ...                ...
# 8042   Office Supplies
# 8043         Furniture
# 8044   Office Supplies
# 8045   Office Supplies
# 8046   Office Supplies
#
# [8047 rows x 6 columns]

# %%
df_order_breakdown.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8047 entries, 0 to 8046
# Data columns (total 6 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Order ID                       8047 non-null   object
#  1   Product Name                   8047 non-null   object
#  2   Discount per product           8047 non-null   float64
#  3   Total revenue before discount  8043 non-null   float64
#  4   Total quantity                 8045 non-null   float64
#  5   Category                       8047 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 440.1+ KB

# %%
# no missing values for order id

df_order_breakdown.isna().sum()
# Out:
# Order ID                         0
# Product Name                     0
# Discount per product             0
# Total revenue before discount    4
# Total quantity                   2
# Category                         0
# dtype: int64

# %%
# rows with missing values (there are no missing values here in any rows)

df_order_breakdown[df_order_breakdown.isna().sum(axis=1) >= 1]
# Out:
#               Order ID                                       Product Name  \
# index
# 4038   ES-2013-5430201        Ames Clasp Envelope, with clear poly window
# 4718   ES-2014-2353233  Smead Legal Exhibit Labels, Laser Printer Comp...
# 5550   ES-2014-4357731                            Acme Scissors, Serrated
# 5987   ES-2014-5500680                           Rogers Box, Single Width
# 6033   ES-2014-5605089                   Sanford Highlighters, Easy-Erase
# 6568   IT-2011-5348771                       Eldon Shelving, Single Width
#
#        Discount per product  Total revenue before discount  Total quantity  \
# index
# 4038                    0.0                            NaN             3.0
# 4718                    3.0                           30.0             NaN
# 5550                    0.0                          111.0             NaN
# 5987                    0.1                            NaN             1.0
# 6033                    0.0                            NaN             2.0
# 6568                    0.1                            NaN             9.0
#
#               Category
# index
# 4038   Office Supplies
# 4718   Office Supplies
# 5550   Office Supplies
# 5987   Office Supplies
# 6033   Office Supplies
# 6568   Office Supplies

# %%
df_order_breakdown.describe(include='all')
# Out:
#                Order ID                   Product Name  Discount per product  \
# count              8047                           8047           8047.000000
# unique             4117                           1810                   NaN
# top     ES-2014-5605089  Eldon File Cart, Single Width                   NaN
# freq                 11                             26                   NaN
# mean                NaN                            NaN              2.577321
# std                 NaN                            NaN              4.611065
# min                 NaN                            NaN              0.000000
# 25%                 NaN                            NaN              0.000000
# 50%                 NaN                            NaN              0.000000
# 75%                 NaN                            NaN              3.000000
# max                 NaN                            NaN             25.500000
#
#         Total revenue before discount  Total quantity         Category
# count                     8043.000000     8045.000000             8047
# unique                            NaN             NaN                3
# top                               NaN             NaN  Office Supplies
# freq                              NaN             NaN             5286
# mean                       291.931369        3.772032              NaN
# std                        485.304890        2.203584              NaN
# min                          3.000000        1.000000              NaN
# 25%                         49.000000        2.000000              NaN
# 50%                        117.000000        3.000000              NaN
# 75%                        313.000000        5.000000              NaN
# max                       6517.000000       14.000000              NaN
